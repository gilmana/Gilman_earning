# %%
import pandas as pd

# %%
inst1 = {
    'Flex Sample ID': ['R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045'],
 'Flex date/time': ['2020-10-04 13:19:00',
  '2020-10-05 13:29:00',
  '2020-10-06 13:40:00',
  '2020-10-07 09:23:00',
  '2020-10-07 13:29:00',
  '2020-10-08 09:24:00',
  '2020-10-08 09:28:00',
  '2020-10-09 10:11:00'],
 'Gln': [0.13, 0.25, 0.78, 1.07, 1.24, 1.0, 1.16, 0.75],
 'Glu': [3.25, 3.32, 3.71, 4.21, 4.56, 4.51, 4.34, 4.55],
 'Gluc': [3.05, 2.95, 1.38, 2.41, 3.32, 3.79, 3.73, 4.23],
 'Lac': [1.96, 1.97, 4.45, 3.42, 2.99, 2.07, 2.06, 1.48],
 'NH4+': [2.05, 2.22, 2.56, 2.33, 2.5, 2.65, 2.58, 2.84],
 'Na+': [131.5, 128.1, 154.3, 124.8, 134.6, 114.5, 113.5, 109.5],
 'K+': [14.95, 14.52, 14.61, 13.57, 14.67, 14.21, 13.87, 13.1],
 'Ca++': [0.13, 0.14, 0.13, 0.11, 0.12, 0.1, 0.1, 0.11]
}

inst2 = {
    'Vicell Sample ID': ['R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045',
  'R0045'],
 'Vicell date/time': ['2020-10-04 13:26:15',
  '2020-10-05 13:46:18',
  '2020-10-05 14:20:36',
  '2020-10-06 13:47:32',
  '2020-10-07 09:30:04',
  '2020-10-07 11:19:56',
  '2020-10-07 13:35:54',
  '2020-10-07 13:39:39',
  '2020-10-08 09:32:03',
  '2020-10-08 09:37:32'],
 'Viability(%)': [86.9, 87.9, 85.8, 86.8, 86.3, 85.3, 84.4, 86.5, 83.2, 82.7],
 'Viable cells/ml (x10^6)': [71.2,
  77.3,
  71.1,
  66.6,
  62.0,
  70.0,
  59.0,
  63.3,
  48.3,
  48.5]
}

############ converting to Dataframe#########
inst1 = pd.DataFrame(inst1)
inst2 = pd.DataFrame(inst2)


########## converting str to datetome ###########
inst1["Flex date/time"] = pd.to_datetime(inst1["Flex date/time"])
inst2["Vicell date/time"] = pd.to_datetime(inst2["Vicell date/time"])
