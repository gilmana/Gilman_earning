# %% [markdown]
# ### matplotlib.pyplot has a dual interface - a MATLAB style and a python object oriented stlye
#
# Playing with the different interfaces to understand the object nature of plotting.
#
# Following along from Jake Vanderplas: http://nbviewer.jupyter.org/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/04.00-Introduction-To-Matplotlib.ipynb
#
# Also a very nice guid to matplotlib:
# https://github.com/WeatherGod/AnatomyOfMatplotlib/blob/master/AnatomyOfMatplotlib-Part1-Figures_Subplots_and_layouts.ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
x = np.linspace(0,10,num=100) #arrey of 100 numbers evenly spaced between 0 and 10

# %% [markdown]
# ### Object oriented interface

# %%
plt.subplots?

# %%
fig, ax = plt.subplots(2,1)  #*fig* is the :class:`matplotlib.figure.Figure` object
                            # *ax* can be either a single axis object or an array of axis

# %%
fig1, ax1 = plt.subplots(2,2)

# %%
fig2, ax2 = plt.subplots(1,2, sharey = True)

# %%
# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));
fig

# %%
# Call plot() method on the appropriate object
ax1[0,1].plot(x, np.sin(x))
ax1[1,1].plot(x, np.cos(x));
fig1

# %%
fig

# %%
#The MATLAB style code

# %% [markdown]
# ### Solution from stack exchange to multiple y-axis:

# %%
#Solution for multiple y axis from stack exchange (matplotlib: overlay plots with different scales?) 
#answer by Joe Kington 
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1977)

fig, ax = plt.subplots()

# Twin the x-axis twice to make independent y-axes.
axes = [ax, ax.twinx(), ax.twinx()]

# Make some space on the right side for the extra y-axis.
fig.subplots_adjust(right=0.75)

# Move the last y-axis spine over to the right by 20% of the width of the axes
axes[-1].spines['right'].set_position(('axes', 1.2))

# To make the border of the right-most axis visible, we need to turn the frame
# on. This hides the other plots, however, so we need to turn its fill off.
axes[-1].set_frame_on(True)
axes[-1].patch.set_visible(False)

# And finally we get to plot things...
colors = ('Green', 'Red', 'Blue')
for ax, color in zip(axes, colors):
    data = np.random.random(1) * np.random.random(10)
    ax.plot(data, marker='o', linestyle='none', color=color)
    ax.set_ylabel('%s Thing' % color, color=color)
    ax.tick_params(axis='y', colors=color)
axes[0].set_xlabel('X-axis')

plt.show()

# %% [markdown]
# # Junk scraps of code below

# %%
List_1 = [0,1,2,3,4,5]
type(List_1)
# Out:
# list

# %%
Tuple_1 = (0,1,2,3,4,5)
type(Tuple_1)
# Out:
# tuple
