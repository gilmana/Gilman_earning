# %%
import seaborn as sns
import numpy as np
import pandas as pd
import string
from random import choice

# %% [markdown]
# # Index

# %%
# Sample dataset, may not need
planets = sns.load_dataset('planets')

# %%
#view of the dataset
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# 5     Radial Velocity       1      185.840000   4.80     76.39  2008
# 6     Radial Velocity       1     1773.400000   4.64     18.15  2002
# 7     Radial Velocity       1      798.500000    NaN     21.41  1996
# 8     Radial Velocity       1      993.300000  10.30     73.10  2008
# 9     Radial Velocity       2      452.800000   1.99     74.79  2010
# 10    Radial Velocity       2      883.000000   0.86     74.79  2010
# 11    Radial Velocity       1      335.100000   9.88     39.43  2009
# ...               ...     ...             ...    ...       ...   ...
# 1023          Transit       1        2.175176    NaN    550.00  2012
# 1024          Transit       1        3.662387    NaN    240.00  2012
# 1025          Transit       1        3.067850    NaN     60.00  2012
# 1026          Transit       1        0.925542    NaN    470.00  2014
# 1027          Imaging       1             NaN    NaN     19.20  2011
# 1028          Transit       1        3.352057    NaN   3200.00  2012
# 1029          Imaging       1             NaN    NaN     10.10  2012
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
#data shape, notice that index is not part of the data
planets.shape
# Out:
# (1035, 6)

# %%
#axis 1 index
planets.columns
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
#axis 0 index
planets.index
# Out:
# RangeIndex(start=0, stop=1035, step=1)

# %%
#set an index
planets.set_index("method")
# Out:
#                  number  orbital_period   mass  distance  year
# method
# Radial Velocity       1      269.300000   7.10     77.40  2006
# Radial Velocity       1      874.774000   2.21     56.95  2008
# Radial Velocity       1      763.000000   2.60     19.84  2011
# Radial Velocity       1      326.030000  19.40    110.62  2007
# Radial Velocity       1      516.220000  10.50    119.47  2009
# Radial Velocity       1      185.840000   4.80     76.39  2008
# Radial Velocity       1     1773.400000   4.64     18.15  2002
# Radial Velocity       1      798.500000    NaN     21.41  1996
# Radial Velocity       1      993.300000  10.30     73.10  2008
# Radial Velocity       2      452.800000   1.99     74.79  2010
# Radial Velocity       2      883.000000   0.86     74.79  2010
# Radial Velocity       1      335.100000   9.88     39.43  2009
# ...                 ...             ...    ...       ...   ...
# Transit               1        2.175176    NaN    550.00  2012
# Transit               1        3.662387    NaN    240.00  2012
# Transit               1        3.067850    NaN     60.00  2012
# Transit               1        0.925542    NaN    470.00  2014
# Imaging               1             NaN    NaN     19.20  2011
# Transit               1        3.352057    NaN   3200.00  2012
# Imaging               1             NaN    NaN     10.10  2012
# Transit               1        3.941507    NaN    172.00  2006
# Transit               1        2.615864    NaN    148.00  2007
# Transit               1        3.191524    NaN    174.00  2007
# Transit               1        4.125083    NaN    293.00  2008
# Transit               1        4.187757    NaN    260.00  2008
#
# [1035 rows x 5 columns]

# %%
#Index stays with the data, even single column Series
planets.distance
# Out:
# 0         77.40
# 1         56.95
# 2         19.84
# 3        110.62
# 4        119.47
# 5         76.39
# 6         18.15
# 7         21.41
# 8         73.10
# 9         74.79
# 10        74.79
# 11        39.43
#          ...
# 1023     550.00
# 1024     240.00
# 1025      60.00
# 1026     470.00
# 1027      19.20
# 1028    3200.00
# 1029      10.10
# 1030     172.00
# 1031     148.00
# 1032     174.00
# 1033     293.00
# 1034     260.00
# Name: distance, Length: 1035, dtype: float64

# %%
#Index stays with the data even if it is sorted
planets[planets.year == 2006]
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000  7.100     77.40  2006
# 36            Imaging       1             NaN    NaN     18.39  2006
# 50    Radial Velocity       1      594.900000  7.600     47.53  2006
# 90            Imaging       1             NaN    NaN       NaN  2006
# 141   Radial Velocity       1     1845.000000  0.910      8.77  2006
# 151           Transit       1        4.465293    NaN    139.00  2006
# 236   Radial Velocity       1      989.200000  0.940     17.35  2006
# 267   Radial Velocity       1      591.900000  1.900     36.02  2006
# 271   Radial Velocity       1     1214.000000  1.500     89.13  2006
# 275   Radial Velocity       1     3668.000000  4.010     46.51  2006
# 291   Radial Velocity       1       18.179000  0.330     86.88  2006
# 345   Radial Velocity       1      589.640000  2.900     10.34  2006
# 352   Radial Velocity       3        8.667000  0.033     12.58  2006
# 353   Radial Velocity       3       31.560000  0.038     12.58  2006
# 354   Radial Velocity       3      197.000000  0.058     12.58  2006
# 380   Radial Velocity       1        2.137500  1.500     91.16  2006
# 410   Radial Velocity       1        4.113775  0.450     28.98  2006
# 498   Radial Velocity       1     3342.000000  0.947     18.06  2006
# 512   Radial Velocity       2     1178.400000  2.100     52.72  2006
# 517   Radial Velocity       4      310.550000    NaN     15.28  2006
# 552   Radial Velocity       1        6.838000  0.940     47.37  2006
# 553   Radial Velocity       1      986.000000  0.750     44.98  2006
# 577           Imaging       1             NaN    NaN     40.85  2006
# 616   Radial Velocity       1       26.730000  0.710     94.07  2006
# 629   Radial Velocity       3      147.730000  1.280     52.88  2006
# 651           Transit       1        2.470630    NaN    213.00  2006
# 919      Microlensing       1     3300.000000    NaN       NaN  2006
# 937           Imaging       1   730000.000000    NaN       NaN  2006
# 951           Transit       1        4.200000    NaN   8500.00  2006
# 952           Transit       1        1.796000    NaN   8500.00  2006
# 1030          Transit       1        3.941507    NaN    172.00  2006

# %% [markdown]
# # Pivot

# %%
from IPython.display import Image
Image(filename='sample.jpg')

# %%
#create my own dataset

sample_id = np.arange(1,6).repeat(2)
target = [i for i in "AB"*5]
ph = np.random.normal(7, 0.5, 10).round(1) #normal distribution with mu = 7 and sigma = 0.5, rounded to single decimal
viral_count = np.random.randint(500, 10000, 10)
waste_site = ["".join(choice(string.ascii_letters) for i in range(10)) for x in range(10)]
flow_rate = np.random.randint(50,150, 10)

data_dict = {"sample_id": sample_id,
             "target":target,
             "ph":ph,
             "viral_count":viral_count,
             "waste_site": waste_site,
             "flow_rate": flow_rate
            }

df = pd.DataFrame(data_dict)

# %%
#view dataframe
df
# Out:
#    sample_id target   ph  viral_count  waste_site  flow_rate
# 0          1      A  6.9         6003  fKWZQnWonN        103
# 1          1      B  7.8         7218  wLVyaFQMpT         51
# 2          2      A  7.3         9177  zAGRrrlCil        133
# 3          2      B  8.1         1349  zHaXExOZRP        142
# 4          3      A  7.5         7756  DKzgKiLrsy        140
# 5          3      B  6.9         6520  EZqIRDZfKS        121
# 6          4      A  7.5         4947  arGlreoNWp         81
# 7          4      B  6.8         8910  oaXKdZBtCt        118
# 8          5      A  6.5         6694  ztzqUTrOpF         89
# 9          5      B  6.6         1749  iPPdpUIcSd        130

# %%
#explore pivot function
df.pivot?

# %%
#apply pivot function while omitting index
df.pivot(columns = "target")
# Out:
#        sample_id        ph      viral_count          waste_site              \
# target         A    B    A    B           A       B           A           B
# 0            1.0  NaN  6.9  NaN      6003.0     NaN  fKWZQnWonN         NaN
# 1            NaN  1.0  NaN  7.8         NaN  7218.0         NaN  wLVyaFQMpT
# 2            2.0  NaN  7.3  NaN      9177.0     NaN  zAGRrrlCil         NaN
# 3            NaN  2.0  NaN  8.1         NaN  1349.0         NaN  zHaXExOZRP
# 4            3.0  NaN  7.5  NaN      7756.0     NaN  DKzgKiLrsy         NaN
# 5            NaN  3.0  NaN  6.9         NaN  6520.0         NaN  EZqIRDZfKS
# 6            4.0  NaN  7.5  NaN      4947.0     NaN  arGlreoNWp         NaN
# 7            NaN  4.0  NaN  6.8         NaN  8910.0         NaN  oaXKdZBtCt
# 8            5.0  NaN  6.5  NaN      6694.0     NaN  ztzqUTrOpF         NaN
# 9            NaN  5.0  NaN  6.6         NaN  1749.0         NaN  iPPdpUIcSd
#
#        flow_rate
# target         A      B
# 0          103.0    NaN
# 1            NaN   51.0
# 2          133.0    NaN
# 3            NaN  142.0
# 4          140.0    NaN
# 5            NaN  121.0
# 6           81.0    NaN
# 7            NaN  118.0
# 8           89.0    NaN
# 9            NaN  130.0

# %%
#set index to sample_id for the pivot
df.pivot(columns = "target", index = "sample_id")
# Out:
#             ph      viral_count        waste_site             flow_rate
# target       A    B           A     B           A           B         A    B
# sample_id
# 1          6.9  7.8        6003  7218  fKWZQnWonN  wLVyaFQMpT       103   51
# 2          7.3  8.1        9177  1349  zAGRrrlCil  zHaXExOZRP       133  142
# 3          7.5  6.9        7756  6520  DKzgKiLrsy  EZqIRDZfKS       140  121
# 4          7.5  6.8        4947  8910  arGlreoNWp  oaXKdZBtCt        81  118
# 5          6.5  6.6        6694  1749  ztzqUTrOpF  iPPdpUIcSd        89  130

# %%
#select only desired columns 
df.pivot(columns = "target", index = "sample_id", values = ["ph", "viral_count", "flow_rate"])
# Out:
#             ph      viral_count         flow_rate
# target       A    B           A       B         A      B
# sample_id
# 1          6.9  7.8      6003.0  7218.0     103.0   51.0
# 2          7.3  8.1      9177.0  1349.0     133.0  142.0
# 3          7.5  6.9      7756.0  6520.0     140.0  121.0
# 4          7.5  6.8      4947.0  8910.0      81.0  118.0
# 5          6.5  6.6      6694.0  1749.0      89.0  130.0

# %%
#some magic to rename and collapse multi-index columns
df_piv = df.pivot(columns = "target", index = "sample_id", values = ["ph", "viral_count", "flow_rate"])
df_piv.columns = ["_".join(col) for col in df_piv.columns.values]
df_piv
# Out:
#            ph_A  ph_B  viral_count_A  viral_count_B  flow_rate_A  flow_rate_B
# sample_id
# 1           6.9   7.8         6003.0         7218.0        103.0         51.0
# 2           7.3   8.1         9177.0         1349.0        133.0        142.0
# 3           7.5   6.9         7756.0         6520.0        140.0        121.0
# 4           7.5   6.8         4947.0         8910.0         81.0        118.0
# 5           6.5   6.6         6694.0         1749.0         89.0        130.0

# %% [markdown]
# # Pivot Table

# %%
#display original dataframe
df
# Out:
#    sample_id target   ph  viral_count  waste_site  flow_rate
# 0          1      A  6.9         6003  fKWZQnWonN        103
# 1          1      B  7.8         7218  wLVyaFQMpT         51
# 2          2      A  7.3         9177  zAGRrrlCil        133
# 3          2      B  8.1         1349  zHaXExOZRP        142
# 4          3      A  7.5         7756  DKzgKiLrsy        140
# 5          3      B  6.9         6520  EZqIRDZfKS        121
# 6          4      A  7.5         4947  arGlreoNWp         81
# 7          4      B  6.8         8910  oaXKdZBtCt        118
# 8          5      A  6.5         6694  ztzqUTrOpF         89
# 9          5      B  6.6         1749  iPPdpUIcSd        130

# %%
#explore pivot table
df.pivot_table?

# %%
# pivot table around single column, default agg function
df.pivot_table(columns = "target")
# Out:
# target             A        B
# flow_rate     109.20   112.40
# ph              7.14     7.24
# sample_id       3.00     3.00
# viral_count  6915.40  5149.20

# %%
# pivot table around single column, default agg function
df.pivot_table(columns = "target", aggfunc = "sum")
# Out:
# target             A        B
# flow_rate      546.0    562.0
# ph              35.7     36.2
# sample_id       15.0     15.0
# viral_count  34577.0  25746.0

# %%
#pivot tables can appear aconfusing quickly - the same principles apply
df.pivot_table(columns = "target", index = ["waste_site", "sample_id"])
# Out:
#                      flow_rate          ph      viral_count
# target                       A      B    A    B           A       B
# waste_site sample_id
# DKzgKiLrsy 3             140.0    NaN  7.5  NaN      7756.0     NaN
# EZqIRDZfKS 3               NaN  121.0  NaN  6.9         NaN  6520.0
# arGlreoNWp 4              81.0    NaN  7.5  NaN      4947.0     NaN
# fKWZQnWonN 1             103.0    NaN  6.9  NaN      6003.0     NaN
# iPPdpUIcSd 5               NaN  130.0  NaN  6.6         NaN  1749.0
# oaXKdZBtCt 4               NaN  118.0  NaN  6.8         NaN  8910.0
# wLVyaFQMpT 1               NaN   51.0  NaN  7.8         NaN  7218.0
# zAGRrrlCil 2             133.0    NaN  7.3  NaN      9177.0     NaN
# zHaXExOZRP 2               NaN  142.0  NaN  8.1         NaN  1349.0
# ztzqUTrOpF 5              89.0    NaN  6.5  NaN      6694.0     NaN

# %% [markdown]
# # Wide to long transform: melt

# %% [markdown]
# # Appendix
