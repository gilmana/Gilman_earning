# %%
import numpy as np
import matplotlib.pyplot as plt



# %matplotlib inline

# %% [markdown]
# # Part #1

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set(xlim = [0,10], ylim = [-2,8], title = "Example Title",
       ylabel = "Y-lab", xlabel = "X-lab")
# Out:
# [(-2, 8),
#  Text(0,0.5,'Y-lab'),
#  (0, 10),
#  Text(0.5,0,'X-lab'),
#  Text(0.5,1,'Example Title')]

# %%
x = np.linspace(0,(2*3.14)*2,1000)

# %%
y = np.cos(x)

# %%
fig, ax = plt.subplots(nrows = 3 , ncols = 1, figsize = (5,4))

ax[0].plot(x,y)
ax[0].set(title = "Signal 1", xticks = [], yticks = [])
ax[1].plot(x, np.cos(x + (3.14/4)))
ax[1].set(title = "Signal 2", xticks = [], yticks = [])
ax[2].plot(x, np.cos(x + 3.13/2))
ax[2].set(title = "Signal 3", xticks = [], yticks = [])

plt.tight_layout()

# %% [markdown]
# # Part #2 Plotting Methods Overview

# %%
np.random.seed(1)
x = np.arange(5)
y = np.random.randn(5)

# %%
fig, axes = plt.subplots(ncols = 2, figsize = plt.figaspect(1/2))
axes[0].bar(x,y,)
axes[1].barh(x,y)

#draw horizontal line

vert_bars = axes[0].axhline(0, color= "black", linewidth = 1)
horiz_bars = axes[1].axvline(0, color = "black", linewidth = 1)

# %%
alist = ["a","b","c","d"]
for i in enumerate(alist):
    print(i)
a = list(enumerate(alist))
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')
# (3, 'd')

# %%
fig, axe = plt.subplots()
vert_bars = axe.bar(x,y, color = "lightblue")

for bar, height in zip(vert_bars, y):
    if height < 0:
        bar.set(color = "salmon", linewidth = 3)
        bar.set(edgecolor = "darkred")

# %%
np.random.seed(1)

y = np.random.randn(100).cumsum()
x = np.linspace(0,10,100)

fig, axe = plt.subplots()
axe.plot(x,y)
axe.fill_between(x,y, color = "lightblue")

# %%
x = np.linspace(0,10,200)
y1 = 2*x +1
y2 = 3*x +1.2
y_mean = 0.5*x + np.cos(x*2) + 2.5*x + 1.1

fig, axe = plt.subplots()

axe.plot(x,y1)
axe.plot(x,y2)
axe.plot(x,y_mean)

axe.fill_between(x,y1,y2, color = "yellow")

# %%
np.random.seed(2)

x = np.linspace(0,24,500)
y_0= 2*x + 8
y_1 = np.random.randn(500).cumsum()
y_2 = y_0 + y_1

# %%
fig, axe = plt.subplots()
axe.set(ylim = [-10,100], xlim = [0,30])

axe.plot(x,y_0)
axe.plot(x, y_1)
axe.plot(x,y_2, color = "salmon")

# %%
#reshape to 10 rows (and however columns), then take average across rows. 
y_2_10 = y_2.reshape(10,-1).mean(axis = 1)

# %%
#step all the x values by 1/10 of total, then add 1 to make total of 10 x axis spots. 
x_bar = x[::(int(500/10)+1)]

# %%
fig, axes = plt.subplots()
axes.bar(x_bar,y_2_10)
# Out:
# <BarContainer object of 10 artists>

# %%
#Ploting them together
fig, ax = plt.subplots()

ax.set(xlim = [0,30], ylim = [0,100])

ax.plot(x,y_2, color = "salmon")
ax.bar(x_bar,y_2_10, color = "tan", width = 2.5, edgecolor = "black")#, yerr = error, error_kw = dict(lw=1, capsize=2, capthick=1))
# Out:
# <BarContainer object of 10 artists>

# %%
#Adding error bars as +/- 3 std. dev.

# %%
error = y_2.reshape(10,-1).std(axis = 1)*3

fig, ax = plt.subplots()

ax.set(xlim = [0,30], ylim = [0,100])

ax.plot(x,y_2, color = "salmon")
ax.bar(x_bar,y_2_10, color = "tan", width = 2.5, edgecolor = "black", yerr = error, error_kw = dict(lw=1, capsize=2, capthick=1))
# Out:
# <BarContainer object of 10 artists>

# %%
#Ploting them together and cleaning up with kwargs

# %%
error_bars = dict(lw=1, capsize=2, capthick=1)
bar_args = dict(color = "tan", width = 2.5, edgecolor = "black")

# %%
fig, ax = plt.subplots()
fig.suptitle("Future Projection of Attitutes")

ax.set(xlim = [0,30], ylim = [0,100])
ax.set_ylabel("Snarkiness (snark units)")
ax.set_xlabel("Minutes since class began")

line, = ax.plot(x,y_2, color = "salmon")#, label = "plot line")
line.set_label('line')

bar = ax.bar(x_bar,y_2_10, yerr = error, error_kw = error_bars, **bar_args) #label = "bars + errors"
bar.set_label("bar")


ax.legend()

# %%
#And Lastly adding projections fill between area

# %%
x_projected = np.arange(0,40,1)
y_top = x_projected*2.3 + 30
y_bottome = x_projected*0.667 + 5

# %%
fig, ax = plt.subplots()
fig.suptitle("Future Projection of Attitutes")

ax.set(xlim = [0,30], ylim = [0,100])
ax.set_ylabel("Snarkiness (snark units)")
ax.set_xlabel("Minutes since class began")

line, = ax.plot(x,y_2, color = "salmon")#, label = "plot line")
line.set_label('line')

bar = ax.bar(x_bar,y_2_10, yerr = error, error_kw = error_bars, **bar_args) #label = "bars + errors"
bar.set_label("bar")

fill = ax.fill_between(x_projected, y_top, y_bottome, color = "lightblue")


ax.legend()

# %% [markdown]
# #### Colorbars

# %%
from matplotlib.cbook import get_sample_data

# %%
data = np.load(get_sample_data('axes_grid\\bivariate_normal.npy'))

# %%
fig, ax = plt.subplots()

im = ax.imshow(data, cmap = "gist_earth")
fig.colorbar(im)

# %%
fig, ax = plt.subplots()
cax = fig.add_axes([0.27, 0.8, 0.5, 0.05])

im = ax.imshow(data, cmap='gist_earth')
fig.colorbar(im, cax=cax, orientation='horizontal')

# %%
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='seismic', interpolation='nearest')
fig.colorbar(im)

# %%
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='seismic', interpolation='nearest',
               vmin=-2, vmax=2)
fig.colorbar(im)

# %% [markdown]
# ### Excercise 2.2

# %%
array_1 = np.random.random((10,10))
array_2 = np.random.random((10,10))*2
array_3 = np.random.random((10,10))*3

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize = plt.figaspect(1/2))

ax1 = ax[0].imshow(array_1, cmap = "jet", vmin = 0, vmax = 3)
ax2 = ax[1].imshow(array_2, cmap = "jet", vmin = 0, vmax = 3)
ax3 = ax[2].imshow(array_3, cmap = "jet", vmin = 0, vmax = 3)

cbar_axes = fig.add_axes([0.25, 0.1, 0.5, 0.05])

fig.colorbar(ax1, cax = cbar_axes, orientation = "horizontal")

# %%
#Making it concise and robust
fig, ax = plt.subplots(nrows=1, ncols =3, figsize = plt.figaspect(1/2))

kwargs = dict(cmap = "jet", vmin = 0, vmax = 3) #arguments for all axes

n = 1 #counter to multiply the 10x10 random array
for i in ax.flat:
    im = i.imshow(np.random.random((10,10))*n, **kwargs) #cmap = "jet", vmin = 0, vmax = 3)
    n += 1
    
cbar_axes = fig.add_axes([0.25,0.1,0.5,0.05])

fig.colorbar(im, cax = cbar_axes, orientation = "horizontal")

# %% [markdown]
# # Part #3 How to speak Matplotlib

# %% [markdown]
# ### Excercise 3.1

# %%
t = np.arange(0.0, 5.0, 0.2)
plt.plot(t, t, t, t**2,t, t**3, )
# Out:
# [<matplotlib.lines.Line2D at 0x216f0ac8898>,
#  <matplotlib.lines.Line2D at 0x216f0ac89e8>,
#  <matplotlib.lines.Line2D at 0x216ecffb198>]

# %%
#completely understand what a meshgrid does:

#https://stackoverflow.com/questions/36013063/what-is-the-purpose-of-meshgrid-in-python-numpy

# %%
xs, ys = np.mgrid[:4, 9:0:-1]
markers = [".", "+", ",", "x", "o", "D", "d", "", "8", "s", "p", "*", "|", "_", "h", "H", 0, 4, "<", "3",
           1, 5, ">", "4", 2, 6, "^", "2", 3, 7, "v", "1", "None", None, " ", ""]
descripts = ["point", "plus", "pixel", "cross", "circle", "diamond", "thin diamond", "",
             "octagon", "square", "pentagon", "star", "vertical bar", "horizontal bar", "hexagon 1", "hexagon 2",
             "tick left", "caret left", "triangle left", "tri left", "tick right", "caret right", "triangle right", "tri right",
             "tick up", "caret up", "triangle up", "tri up", "tick down", "caret down", "triangle down", "tri down",
             "Nothing", "Nothing", "Nothing", "Nothing"]
fig, ax = plt.subplots(1, 1, figsize=(7.5, 4))
for x, y, m, d in zip(xs.T.flat, ys.T.flat, markers, descripts):
    ax.scatter(x, y, marker=m, s=100)
    ax.text(x + 0.1, y - 0.1, d, size=14)
ax.set_axis_off()
plt.show()

# %%
t = np.arange(0.0, 5.0, 0.2)
plt.plot(t, t, '-', t, t**2, '--', t, t**3, '-.', t, -t, ':')
# Out:
# [<matplotlib.lines.Line2D at 0x216f21210f0>,
#  <matplotlib.lines.Line2D at 0x216f21212b0>,
#  <matplotlib.lines.Line2D at 0x216f2121ac8>,
#  <matplotlib.lines.Line2D at 0x216f2121f28>]

# %%
fig, ax = plt.subplots()
ax.bar([1,2,3,4],[10,20,15,13], ls = "dashed", ec = "r", lw = "5")
# Out:
# <BarContainer object of 4 artists>

# %%
t = np.arange(0., 5., 0.2)
# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
# Out:
# [<matplotlib.lines.Line2D at 0x216f21e9ba8>,
#  <matplotlib.lines.Line2D at 0x216f21e9d68>,
#  <matplotlib.lines.Line2D at 0x216f21f05c0>]

# %%
t = np.arange(0.0, 5.0, 0.1)
a = np.exp(-t) * np.cos(2*np.pi*t)
plt.plot(t, a, )

# %%
# %load http://matplotlib.org/mpl_examples/color/colormaps_reference.py
"""
==================
Colormap reference
==================

Reference for colormaps included with Matplotlib.

This reference example shows all colormaps included with Matplotlib. Note that
any colormap listed here can be reversed by appending "_r" (e.g., "pink_r").
These colormaps are divided into the following categories:

Sequential:
    These colormaps are approximately monochromatic colormaps varying smoothly
    between two color tones---usually from low saturation (e.g. white) to high
    saturation (e.g. a bright blue). Sequential colormaps are ideal for
    representing most scientific data since they show a clear progression from
    low-to-high values.

Diverging:
    These colormaps have a median value (usually light in color) and vary
    smoothly to two different color tones at high and low values. Diverging
    colormaps are ideal when your data has a median value that is significant
    (e.g.  0, such that positive and negative values are represented by
    different colors of the colormap).

Qualitative:
    These colormaps vary rapidly in color. Qualitative colormaps are useful for
    choosing a set of discrete colors. For example::

        color_list = plt.cm.Set3(np.linspace(0, 1, 12))

    gives a list of RGB colors that are good for plotting a series of lines on
    a dark background.

Miscellaneous:
    Colormaps that don't fit into the categories above.

"""
import numpy as np
import matplotlib.pyplot as plt


# Have colormaps separated into categories:
# http://matplotlib.org/examples/color/colormaps_reference.html
cmaps = [('Perceptually Uniform Sequential', [
            'viridis', 'plasma', 'inferno', 'magma']),
         ('Sequential', [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']),
         ('Sequential (2)', [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']),
         ('Diverging', [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']),
         ('Qualitative', [
            'Pastel1', 'Pastel2', 'Paired', 'Accent',
            'Dark2', 'Set1', 'Set2', 'Set3',
            'tab10', 'tab20', 'tab20b', 'tab20c']),
         ('Miscellaneous', [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'hsv',
            'gist_rainbow', 'rainbow', 'jet', 'nipy_spectral', 'gist_ncar'])]


nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps)
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))


def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps:
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(1,2)
z = np.random.random((10,10))
ax1.imshow(z, cmap = "gray")
ax2.imshow(z, cmap = "coolwarm")

# %%
plt.scatter([1, 2, 3, 4], [4, 3, 2, 1])
plt.title(r'$\sigma_i=15$', fontsize=20)
# Out:
# Text(0.5,1,'$\\sigma_i=15$')

# %%
import matplotlib as mpl
from matplotlib.rcsetup import cycler
mpl.rc('axes', prop_cycle=cycler('color', 'rgc') +
                          cycler('lw', [1, 4, 6]) +
                          cycler('linestyle', ['-', '-.', ':']))
t = np.arange(0.0, 5.0, 0.2)
plt.plot(t, t)
plt.plot(t, t**2)
plt.plot(t, t**3)
plt.show()

# %%
mpl.rc('axes', prop_cycle=cycler('color', ['r', 'orange', 'c', 'y']) +
                          cycler('hatch', ['x', 'xx-', '+O.', '*']))
x = np.array([0.4, 0.2, 0.5, 0.8, 0.6])
y = [0, -5, -6, -5, 0]
plt.fill(x+1, y)
plt.fill(x+2, y)
plt.fill(x+3, y)
plt.fill(x+4, y)
plt.show()

# %%
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\agilman\AppData\Local\Continuum\miniconda3\envs\data_wrangling\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# # Part #4 Limits Legends and Layouts
